# %%
# %%python
# a = 4
# for i in range(a):
#     print(i)
# Out:
# Python code executed successfully.
# ------Output-----
#    0
# 1
# 2
# 3

# %%
drop_all_tables local::DuckDuckConnection
# Out:
# <div style='color:  green;'>Total Time Taken - 1.00s
# </div>
# Dropped tables: sample__sport, sample__tree, test3

# %%
load /home/shannu/Documents/CSV/employee.csv local::DuckDuckConnection
# Out:
# <div style='color:  green;'>Total Time Taken - 0.95s
# </div>
# Beep Sound
# Loaded into table: 'test3'. RowCount: 50

# %%
db local::DuckDuckConnection
# Out:
# <div style='color:  green;'>Total Time Taken - 1.01s
# </div>
# Database local::DB
# (
#   Table sample__sport
#   (
#     Athlete VARCHAR(0),
#     Age BIGINT,
#     Country VARCHAR(0),
#     Year BIGINT,
#     Date DATE,
#     Sport VARCHAR(0),
#     Gold BIGINT,
#     Silver BIGINT,
#     Bronze BIGINT
#   )
#   Table sample__tree
#   (
#     city VARCHAR(0),
#     country VARCHAR(0),
#     year BIGINT,
#     tree BIGINT
#   )
#   Table test3
#   (
#     EMPLOYEE_ID BIGINT,
#     FIRST_NAME VARCHAR(0),
#     LAST_NAME VARCHAR(0),
#     EMAIL VARCHAR(0),
#     PHONE_NUMBER VARCHAR(0),
#     HIRE_DATE VARCHAR(0),
#     JOB_ID VARCHAR(0),
#     SALARY BIGINT,
#     COMMISSION_PCT BIGINT,
#     MANAGER_ID BIGINT,
#     DEPARTMENT_ID BIGINT
#   )
# )

# %%
#>{local::DuckDuckDatabase.test3}#->filter{x|$x.JOB_ID == 'FI_ACCOUNT'}->select(~[EMPLOYEE_ID, FIRST_NAME, LAST_NAME])->from(local::DuckDuckRuntime)
# Out:
# <div style='color:  green;'>Total Time Taken - 0.92s
# </div>
# <div style='color: red;'>Error: Unexpected token</div>

# %%
#>{local::DuckDuckDatabase.test3}#->filter(x|$x.JOB_ID == 'FI_ACCOUNT')->select(~[EMPLOYEE_ID])->from(local::DuckDuckRuntime)
# Out:
# <div style='color:  green;'>Total Time Taken - 1.13s
# </div>
#    EMPLOYEE_ID
# 0          109
# 1          110
# 2          111
# 3          112
# 4          113

# %%
macro JOB_CHECKER = $x.JOB_ID == 'FI_ACCOUNT'
# Out:
# <div style='color:  green;'>Macro Established in - 0.88s
# </div>
# Macro 'JOB_CHECKER' defined.

# %%
macro MY_TABLE = {local::DuckDuckDatabase.test3}
# Out:
# <div style='color:  green;'>Macro Established in - 1.00s
# </div>
# Macro 'MY_TABLE' defined.

# %%
macro MY_RUNTIME = from(local::DuckDuckRuntime)
# Out:
# <div style='color:  green;'>Macro Established in - 0.94s
# </div>
# Macro 'MY_RUNTIME' defined.

# %%
#>{local::DuckDuckDatabase.test3}#->filter(x|macro{JOB_CHECKER})->select(~[EMPLOYEE_ID])->from(local::DuckDuckRuntime)
# Out:
# <div style='color:  green;'>Total Time Taken - 1.10s
# </div>
#    EMPLOYEE_ID
# 0          109
# 1          110
# 2          111
# 3          112
# 4          113

# %%
#>{local::DuckDuckDatabase.test3}#->filter(x|macro{JOB_CHECKER})->select(~[EMPLOYEE_ID])->macro{MY_RUNTIME}
# Out:
# <div style='color:  green;'>Total Time Taken - 1.04s
# </div>
#    EMPLOYEE_ID
# 0          109
# 1          110
# 2          111
# 3          112
# 4          113

# %%
#>macro{MY_TABLE}#->filter(x|macro{JOB_CHECKER})->select(~[EMPLOYEE_ID])->macro{MY_RUNTIME}
# Out:
# <div style='color:  green;'>Total Time Taken - 1.05s
# </div>
#    EMPLOYEE_ID
# 0          109
# 1          110
# 2          111
# 3          112
# 4          113

# %%
show_macros
# Out:
# <div style='color:  green;'>Macros fetched in- 0.85s
# </div>
# Defined Macros:
#
# macro{MY_TABLE} = {local::DuckDuckDatabase.test3}
#
# macro{JOB_CHECKER} = $x.JOB_ID == 'FI_ACCOUNT'
#
# macro{MY_RUNTIME} = from(local::DuckDuckRuntime)

# %%
macro JOB_CHECKER = $x.JOB_ID == 'FB_ACCOUNT'
# Out:
# <div style='color:  green;'>Macro Established in - 1.00s
# </div>
# Macro 'JOB_CHECKER' defined.

# %%
show_macros
# Out:
# <div style='color:  green;'>Macros fetched in- 0.93s
# </div>
# Defined Macros:
#
# macro{MY_TABLE} = {local::DuckDuckDatabase.test3}
#
# macro{JOB_CHECKER} = $x.JOB_ID == 'FB_ACCOUNT'
#
# macro{MY_RUNTIME} = from(local::DuckDuckRuntime)

# %%
macro JOB_CHECKER = $x.JOB_ID == 'FI_ACCOUNT'
# Out:
# <div style='color:  green;'>Macro Established in - 0.86s
# </div>
# Macro 'JOB_CHECKER' defined.

# %%
show_macros
# Out:
# <div style='color:  green;'>Macros fetched in- 0.99s
# </div>
# Defined Macros:
#
# macro{MY_TABLE} = {local::DuckDuckDatabase.test3}
#
# macro{JOB_CHECKER} = $x.JOB_ID == 'FI_ACCOUNT'
#
# macro{MY_RUNTIME} = from(local::DuckDuckRuntime)

# %%
clear_macros
# Out:
# <div style='color:  green;'>Macros cleared in- 0.96s
# </div>
# All macros cleared.

# %%
show_macros
# Out:
# <div style='color:  green;'>Macros fetched in- 0.90s
# </div>
# Defined Macros:
